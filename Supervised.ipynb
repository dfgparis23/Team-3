# %%
import pandas as pd
import numpy as np

# %%
business_account = pd.read_excel("../shared_data_read_only/Business Account.xlsx")
consumer_price_index = pd.read_excel("../shared_data_read_only/consumer_price_index.xlsx")
contacts = pd.read_excel("../shared_data_read_only/Contacts.xlsx")
data_dictionary = pd.read_excel("../shared_data_read_only/Data dictionary.xlsx")
invoice_opportunities = pd.read_excel("../shared_data_read_only/Invoice and Opportunities.xlsx")
items_opportunities = pd.read_excel("../shared_data_read_only/Items and Opportunities.xlsx")
non_stock_items = pd.read_excel("../shared_data_read_only/Non-Stock Items.xlsx")
opportunities = pd.read_excel("../shared_data_read_only/Opportunities.xlsx")

# %%
#Error finds in the data

# %%
df = df.merge(contacts, how="left", on="")

df = opportunities.merge(business_account, how="left", on="Business Account")

df = df.merge(invoice_opportunities, how="left")
df = df.merge(invoice_opportunities, how="left")
df = df.merge(invoice_opportunities, how="left")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-2e833e9f0616> in <module>
# ----> 1 df = df.merge(contacts, how="left", on="")
#       2
#       3 df = opportunities.merge(business_account, how="left", on="Business Account")
#       4
#       5 df = df.merge(invoice_opportunities, how="left")
#
# NameError: name 'df' is not defined

# %%
df = opportunities.merge(invoice_opportunities, how="left", )

# %%
opportunities[['Theorical payment date 1', 'Theorical payment amount 1',
       'Theorical payment date 2', 'Theorical payment amount 2',
       'Theorical payment date 3', 'Theorical payment amount 3',
       'Theorical payment date 4', 'Theorical payment amount 4',
       'Theorical payment date 5', 'Theorical payment amount 5']].isna().sum()
# Out:
# Theorical payment date 1      5635
# Theorical payment amount 1    5667
# Theorical payment date 2      5884
# Theorical payment amount 2    5887
# Theorical payment date 3      5933
# Theorical payment amount 3    5934
# Theorical payment date 4      5967
# Theorical payment amount 4    5967
# Theorical payment date 5      5976
# Theorical payment amount 5    5976
# dtype: int64

# %%
invoice_opportunities[invoice_opportunities["Customer"]== "C01388"]
# Out:
#          Type Reference Nbr. Customer     Amount       Date  Opportunity ID
# 1     Invoice      FC0004607   C01388  241253.00 2023-10-09            1863
# 580   Invoice      FC0003632   C01388  148686.75 2023-02-21            3844
# 1384  Invoice      FC0002559   C01388  390128.04 2022-06-24            1877
# 1941  Invoice      FC0001908   C01388  643340.00 2022-03-21            1863
# 1950  Invoice      FC0001883   C01388  643340.00 2021-03-21            1863

# %%
invoice_opportunities[invoice_opportunities["Opportunity ID"]== 1863]
# Out:
#          Type Reference Nbr. Customer    Amount       Date  Opportunity ID
# 1     Invoice      FC0004607   C01388  241253.0 2023-10-09            1863
# 1941  Invoice      FC0001908   C01388  643340.0 2022-03-21            1863
# 1950  Invoice      FC0001883   C01388  643340.0 2021-03-21            1863

# %%
opportunities[opportunities["Opportunity ID"]== 1863][['Theorical payment date 1', 'Theorical payment amount 1',
       'Theorical payment date 2', 'Theorical payment amount 2',
       'Theorical payment date 3', 'Theorical payment amount 3',
       'Theorical payment date 4', 'Theorical payment amount 4',
       'Theorical payment date 5', 'Theorical payment amount 5']]
# Out:
#      Theorical payment date 1 Theorical payment amount 1  \
# 4222               2023-06-30                     241189
#
#      Theorical payment date 2 Theorical payment amount 2  \
# 4222                      NaT                        NaN
#
#      Theorical payment date 3 Theorical payment amount 3  \
# 4222                      NaT                        NaN
#
#      Theorical payment date 4 Theorical payment amount 4  \
# 4222                      NaT                        NaN
#
#      Theorical payment date 5 Theorical payment amount 5
# 4222                      NaT                        NaN

# %%
643340.0*2 + 241253.0
# Out:
# 1527933.0

# %%
df = opportunities[["Opportunity ID"]]
invoice_opportunities[invoice_opportunities["Opportunity ID"]==4504]
for id in opportunities[["Opportunity ID"]]:
    liste = []
    invoice_ext = invoice_opportunities[invoice_opportunities["Opportunity ID"]==id]
# Out:
# Empty DataFrame
# Columns: [Type, Reference Nbr., Customer, Amount, Date, Opportunity ID]
# Index: []

# %%
invoice_opportunities[invoice_opportunities["Opportunity ID"]== "006386"]
# Out:
# Empty DataFrame
# Columns: [Type, Reference Nbr., Customer, Amount, Date, Opportunity ID]
# Index: []

# %%
opportunities[opportunities["Opportunity ID"]== 1863]
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 4222            1863           C01388         NaN           2021-05-07   Open
#
#      Stage  Probability  Estimated amount  Amount received  Difference  ...  \
# 4222   Won          700          884593.0         884593.0         0.0  ...
#
#       Theorical payment amount 3  Theorical payment date 4  \
# 4222                         NaN                       NaT
#
#      Theorical payment amount 4 Theorical payment date 5  \
# 4222                        NaN                      NaT
#
#      Theorical payment amount 5              Created On  \
# 4222                        NaN 2021-05-07 12:21:55.300
#
#           Last Modified Date Actual Close Date         Assignment Date  \
# 4222 2023-10-11 10:10:22.427               NaT 2021-05-07 12:17:28.367
#
#      Branch ID
# 4222      SDLV
#
# [1 rows x 43 columns]

# %%
liste_new = opportunities[opportunities["Stage"]=="Dossier posed"]["Opportunity ID"].unique()
liste_new
# Out:
# array([6139, 6077, 6071, 6070, 6069, 6068, 6067, 6066, 6065, 6064, 6062,
#        6061, 6059, 6058, 6056, 6055, 6054, 6052, 6051, 6049, 6048, 6043,
#        6041, 6005, 6004, 5974, 5927, 5917, 5911, 5893, 5874, 5856, 5828,
#        5825, 5819, 5810, 5786, 5717, 5716, 5688, 5607, 5472, 5400, 5363,
#        5312, 5254, 5240, 5202, 4760, 4709, 4650, 4571, 4566, 4565, 4522,
#        4491, 4480, 4478, 4472, 4452, 4448, 4447, 4444, 4281, 3955, 3848,
#        3838, 3837, 3836, 3822, 3814, 3812, 3810, 3807, 3713, 3711, 3710,
#        3610, 3583, 3366, 2995, 2972, 2915, 2914, 2913, 2912, 2908, 2904,
#        2858, 2805, 2725, 2707, 2700, 2614, 2544, 2510, 2481, 2440, 2432,
#        2391, 2378, 2254, 1954, 1856, 1825, 1817, 1784, 1670, 1661, 1634,
#        1633, 1590, 1518, 1515, 1514, 1459, 1455, 1440])

# %%
invoice_opportunities[invoice_opportunities["Opportunity ID"].isin(liste_new)]
# Out:
#          Type Reference Nbr. Customer     Amount       Date  Opportunity ID
# 34    Invoice      FC0004523   C01561    5000.00 2023-09-13            5717
# 129   Invoice      FC0004320   C09362   49000.00 2023-08-11            4447
# 297   Invoice      FC0004041   C00622  200000.00 2023-06-19            2725
# 337   Invoice      FC0003969   C00572   25000.00 2023-06-13            5202
# 806   Invoice      FC0003232   C00042    5000.00 2022-12-29            4709
# 1023  Invoice      FC0002983   C00363   10000.00 2022-10-11            2913
# 1309  Invoice      FC0002639   C01439   50000.00 2022-07-22            1633
# 1310  Invoice      FC0002638   C01439   50000.00 2022-07-22            1634
# 1533  Invoice      FC0002366   C00230     978.94 2022-05-31            3814
# 1555  Invoice      FC0002344   C00230      24.59 2022-06-01            3812
# 1578  Invoice      FC0002321   C00230      68.60 2022-05-31            3810
# ...

# %%
business_account.groupby("Postal Code").count()
# Out:
#              Business Account  Customer Status  Type  Partner type  Class  \
# Postal Code
# 0                         388              388   388            11      4
# 0000                        2                2     2             2      1
# 00000                      55               55    55            35     14
# 01000                       3                3     3             2      2
# 01120                       1                1     1             0      0
# ...                       ...              ...   ...           ...    ...
# SW114PD                     1                1     1             1      1
# SW1E6QT                     1                1     1             1      1
# SW1Y6QW                     1                1     1             1      1
# SW6 1BZ                     1                1     1             1      1
# WC2B 5DH                    1                1     1             1      1
#
# ...

# %%
df_reduced = opportunities[["Opportunity ID", "Business Account", "Status", "Stage"]]

# %%
opportunities
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 0               6387           C00037     35334.0           2023-11-27    New
# 1               6386           C01254     36240.0           2023-10-11    New
# 2               6385           C21512     47640.0           2023-10-11    New
# 3               6384           C21509     47636.0           2023-10-11    New
# 4               6383           C21508     47635.0           2023-10-10    New
# ...              ...              ...         ...                  ...    ...
# 5981               5           C00036         NaN           2020-01-01    Won
# 5982               4           C00024         NaN           2020-01-01    Won
# 5983               3           C00011         NaN           2020-01-01    Won
# 5984               2           C00331         NaN           2020-01-01    Won
# 5985               1           C00331         NaN           2020-01-01    Won
#
# ...

# %%
opportunities[~opportunities["Actual Close Date"].isna()]
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 22              6365           C18115     46338.0           2023-10-25    Won
# 49              6338           C00366     37931.0           2023-11-15    Won
# 106             6281           C04952     47602.0           2023-11-24    Won
# 146             6241           C00137     40123.0           2023-10-03    Won
# 166             6220           C13140         NaN           2023-09-28    Won
# ...              ...              ...         ...                  ...    ...
# 5981               5           C00036         NaN           2020-01-01    Won
# 5982               4           C00024         NaN           2020-01-01    Won
# 5983               3           C00011         NaN           2020-01-01    Won
# 5984               2           C00331         NaN           2020-01-01    Won
# 5985               1           C00331         NaN           2020-01-01    Won
#
# ...

# %%
invoice_opportunities[invoice_opportunities["Opportunity ID"]==1]
# Out:
# Empty DataFrame
# Columns: [Type, Reference Nbr., Customer, Amount, Date, Opportunity ID]
# Index: []

# %%
items_opportunities[items_opportunities["Opportunity ID"]==1]
# Out:
#       Opportunity ID  Line Nbr. Inventory ID    Year  Unit Price  Quantity  \
# 7457               1        1.0      MECENAT  2020.0     10000.0       1.0
#
#         UOM  Ext. Price Currency  Discount Amount  Discount, %  \
# 7457  PIECE     10000.0      EUR              0.0          0.0
#
#               Funded Program Free Item Tax Category
# 7457  Réussite dans la Ville     False            0

# %%
items_opportunities[items_opportunities["Opportunity ID"]==1863]
# Out:
#       Opportunity ID  Line Nbr. Inventory ID    Year  Unit Price  Quantity  \
# 5530            1863        1.0   PARTPUB005  2021.0    198778.0       1.0
# 5531            1863        2.0   PARTPUB005  2022.0    685815.0       1.0
#
#         UOM  Ext. Price Currency  Discount Amount  Discount, %  \
# 5530  PIECE    198778.0      EUR              0.0          0.0
# 5531  PIECE    685815.0      EUR              0.0          0.0
#
#          Funded Program Free Item Tax Category
# 5530  Job dans la Ville     False         TVA0
# 5531  Job dans la Ville     False         TVA0

# %%
884593.

# %%
198778.0+685815.0
# Out:
# 884593.0

# %%
opportunities.columns
# Out:
# Index(['Opportunity ID', 'Business Account', 'Contact ID',
#        'Estimated Close Date', 'Status', 'Stage', 'Probability',
#        'Estimated amount', 'Amount received', 'Difference', 'Owner Name',
#        'Follow-up with', 'Class ID', 'Class', 'Source', 'Source Campaign',
#        'Campaign Name', 'Programme financé', 'Action financée', 'Agreement',
#        'Signature date of the agreement', 'Agreement expiry date',
#        'Duration of agreement (months)',
#        'Deadline for submission of interim report', 'Final report deadline',
#        'Type de contrat', 'Type de financement', 'Zone SDLV',
#        'Theorical payment date 1', 'Theorical payment amount 1',
#        'Theorical payment date 2', 'Theorical payment amount 2',
#        'Theorical payment date 3', 'Theorical payment amount 3',
#        'Theorical payment date 4', 'Theorical payment amount 4',
#        'Theorical payment date 5', 'Theorical payment amount 5', 'Created On',
# ...

# %%
opportunities[["Created On", 'Last Modified Date', 'Actual Close Date', 'Assignment Date', 'Estimated Close Date']] = opportunities[["Created On", 'Last Modified Date', 'Actual Close Date', 'Assignment Date', 'Estimated Close Date']].applymap(pd.to_datetime)
items_opportunities[~items_opportunities["Year"].isna()]
items_opportunities["Year"] = items_opportunities["Year"].apply(int)
invoice_opportunities["Date"] = invoice_opportunities["Date"].apply(pd.to_datetime)
for row in opportunities.index:
    id = opportunities.loc[row, "Opportunity ID"]
    time = 0
    items_filter = items_opportunities[items_opportunities["Opportunity ID"] == id]
    invoice_opportunities_filter = invoice_opportunities[invoice_opportunities["Opportunity ID"] == id]
    y = items_filter["Ext. Price"].sum() + invoice_opportunities_filter["Amount"].sum()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-80-7677827d6097> in <module>
#       1 opportunities[["Created On", 'Last Modified Date', 'Actual Close Date', 'Assignment Date', 'Estimated Close Date']] = opportunities[["Created On", 'Last Modified Date', 'Actual Close Date', 'Assignment Date', 'Estimated Close Date']].applymap(pd.to_datetime)
# ----> 2 items_opportunities["Year"] = items_opportunities["Year"].apply(int)
#       3 invoice_opportunities["Date"] = invoice_opportunities["Date"].apply(pd.to_datetime)
#       4 for row in opportunities.index:
#       5     id = opportunities.loc[row, "Opportunity ID"]
#
# /opt/tljh/user/lib/python3.7/site-packages/pandas/core/series.py in apply(self, func, convert_dtype, args, **kwds)
#    4136             else:
#    4137                 values = self.astype(object)._values
# ...

# %%
invoice_opportunities
# Out:
#          Type Reference Nbr. Customer     Amount       Date  Opportunity ID
# 0     Invoice      FC0004608   C06507    5000.00 2023-10-10            4504
# 1     Invoice      FC0004607   C01388  241253.00 2023-10-09            1863
# 2     Invoice      FC0004605   C19104   83954.00 2023-10-06            5708
# 3     Invoice      FC0004600   C10528    3000.00 2023-06-23            5617
# 4     Invoice      FC0004598   C01196   54531.00 2023-10-09            5829
# ...       ...            ...      ...        ...        ...             ...
# 3233  Invoice      FC0000008   C00087    5000.00 2021-03-11            1410
# 3234  Invoice      FC0000007   C00589    3000.00 2020-03-29            1056
# 3235  Invoice      FC0000005   C00644    4504.95 2021-03-15            1499
# 3236  Invoice      FC0000004   C00644     455.37 2021-03-15            1495
# 3237  Invoice      FC0000003   C00644      67.66 2021-03-15            1494
#
# [3238 rows x 6 columns]

# %%
opportunities[opportunities["Status"]=="Won"]
# Out:
#       Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 22              6365           C18115     46338.0           2023-10-25    Won
# 49              6338           C00366     37931.0           2023-11-15    Won
# 106             6281           C04952     47602.0           2023-11-24    Won
# 146             6241           C00137     40123.0           2023-10-03    Won
# 166             6220           C13140         NaN           2023-09-28    Won
# ...              ...              ...         ...                  ...    ...
# 5981               5           C00036         NaN           2020-01-01    Won
# 5982               4           C00024         NaN           2020-01-01    Won
# 5983               3           C00011         NaN           2020-01-01    Won
# 5984               2           C00331         NaN           2020-01-01    Won
# 5985               1           C00331         NaN           2020-01-01    Won
#
# ...

# %%
df_train = opportunities[opportunities["Status"]=="Won"].copy()
for row in df_train.index:
    try:
        id = opportunities.loc[row, "Opportunity ID"]
        invoice_opportunities_filter = invoice_opportunities[invoice_opportunities["Opportunity ID"] == id]
        y = invoice_opportunities_filter["Amount"].sum()
        time = (opportunities.loc[row, "Actual Close Date"] - opportunities.loc[row, "Created On"]).days
        dt_time = invoice_opportunities_filter["Date"].apply(lambda x : (x-opportunities.loc[row, "Created On"]).days/time)
        weighted_sum = dt_time*invoice_opportunities_filter["Amount"]
        t = weighted_sum.sum()
        df_train.loc[id, "t_average"] = t
        df_train.loc[id, "total_amount"] = y
    except:
        pass

 
y = invoice_opportunities_filter["Amount"].sum()
time = (opportunities.loc[row, "Actual Close Date"] - opportunities.loc[row, "Created On"]).days
dt_time = invoice_opportunities_filter["Date"].apply(lambda x : (x-opportunities.loc[row, "Created On"]).days/time)
weighted_sum = dt_time*invoice_opportunities_filter["Amount"]
t = weighted_sum.sum()
df_train.loc[id, "t_average"] = t
df_train.loc[id, "total_amount"] = y




for row in df_train.index:
    try:
        id = opportunities.loc[row, "Opportunity ID"]
        invoice_opportunities_filter = invoice_opportunities[invoice_opportunities["Opportunity ID"] == id]
        y_mean = invoice_opportunities_filter["Amount"].mean()
        nb_p = len(invoice_opportunities_filter["Amount"])
        if id==6241:
            print(invoice_opportunities_filter)
            print(y_mean, nb_p)
        
        df_train.loc[row,"y_mean"] = y_mean
        df_train.loc[row,"nb_p"] = nb_p
    except:
        pass
# Out:
#        Type Reference Nbr. Customer  Amount       Date  Opportunity ID
# 14  Invoice      FC0004543   C00137  1300.0 2023-10-03            6241
# 1300.0 1

# %%
invoice_opportunities[invoice_opportunities['Opportunity ID']==6241]
# Out:
#        Type Reference Nbr. Customer  Amount       Date  Opportunity ID
# 14  Invoice      FC0004543   C00137  1300.0 2023-10-03            6241

# %%
test = invoice_opportunities[invoice_opportunities["Opportunity ID"]==1863]
test
# Out:
#          Type Reference Nbr. Customer    Amount       Date  Opportunity ID
# 1     Invoice      FC0004607   C01388  241253.0 2023-10-09            1863
# 1941  Invoice      FC0001908   C01388  643340.0 2022-03-21            1863
# 1950  Invoice      FC0001883   C01388  643340.0 2021-03-21            1863

# %%
opportunities[opportunities["Opportunity ID"]==6365]
# Out:
#     Opportunity ID Business Account  Contact ID Estimated Close Date Status  \
# 22            6365           C18115     46338.0           2023-10-25    Won
#
#    Stage  Probability  Estimated amount  Amount received  Difference  ...  \
# 22   Won          200             150.0              NaN      -150.0  ...
#
#     Theorical payment amount 3  Theorical payment date 4  \
# 22                         NaN                       NaT
#
#    Theorical payment amount 4 Theorical payment date 5  \
# 22                        NaN                      NaT
#
#    Theorical payment amount 5              Created On      Last Modified Date  \
# 22                        NaN 2023-10-10 14:43:49.470 2023-10-11 14:47:45.550
#
#    Actual Close Date         Assignment Date Branch ID
# 22        2023-10-11 2023-10-10 14:41:23.223      SDLV
#
# [1 rows x 43 columns]

# %%
opportunities["Stage"].unique()
# Out:
# array(['Won', 'Oral agreement', 'Initial Prospect', 'Advanced Prospect',
#        'Lost', 'Dossier posed'], dtype=object)
